# %% [markdown]
# # NLP Vectorization (Brain of Recommendation Engine)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle



# LOAD FEATURE DATASET
# ---------------------------
df = pd.read_csv("src data/shl_feature_engineered.csv")

print("Dataset Loaded:", df.shape)
# Out:
# Dataset Loaded: (91, 14)

# %%
# TF-IDF VECTORIZATION
# ---------------------------
vectorizer = TfidfVectorizer(stop_words="english")

tfidf_matrix = vectorizer.fit_transform(df["final_features"])

print("TF-IDF Shape:", tfidf_matrix.shape)
# Out:
# TF-IDF Shape: (91, 218)

# %%
# SAVE VECTORS
# ---------------------------
with open("tfidf pkl/tfidf_vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)

with open("tfidf pkl/tfidf_matrix.pkl", "wb") as f:
    pickle.dump(tfidf_matrix, f)

print("Vectorization Completed")
# Out:
# Vectorization Completed
